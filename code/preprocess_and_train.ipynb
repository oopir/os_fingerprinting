# %%
import pickle
import os

from scapy.layers.inet import TCPOptions

from math import log, ceil

import numpy             as np
import pandas            as pd
import tensorflow        as tf
import matplotlib.pyplot as plt

from sklearn                 import svm
from sklearn.compose         import make_column_transformer
from sklearn.preprocessing   import MinMaxScaler, OneHotEncoder, LabelEncoder, LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics         import plot_confusion_matrix, ConfusionMatrixDisplay, top_k_accuracy_score

import warnings
warnings.filterwarnings('ignore')

# %%
# opt_to_num = {opt:i  for i,opt  in enumerate(TCPOptions[1].keys())}
# opt_to_num["NONE"] = -1

def get_os_label(nmap_output):
    osclass = nmap_output[0]['osclass'][0]
    return f"{osclass['osfamily']}_{osclass['osgen']}"
    # return osclass['osfamily']


def preprocess_curr_addr_features(curr_addr_features, curr_addr_label):
    curr_addr_features['label'] = curr_addr_label
    # curr_addr_features['ttl'] //= 10
    curr_addr_features['ttl'] = 2 ** ceil(log(curr_addr_features['ttl'], 2))
    # curr_addr_features['w_size'] //= 1000
    # curr_addr_features['mss'] //= 100
    curr_addr_features.pop('mss')

    return curr_addr_features

# %%
label_dir   = 'C:\\Users\\ofir\\OneDrive - mail.tau.ac.il\\personal\\my_p0f\\data\\ips_label_dict'
feature_dir = 'C:\\Users\\ofir\\OneDrive - mail.tau.ac.il\\personal\\my_p0f\\data\\ips_feature_dict'
all_data    = []

for filename in sorted(os.listdir(label_dir))[:7000]:    
    # print(f'working on {filename}...')
    feature_file = open(f'{feature_dir}\\{filename}', 'rb')
    label_file   = open(f'{label_dir}\\{filename}', 'rb')

    ip_to_features = pickle.load(feature_file)
    ip_to_label    = pickle.load(label_file)
    
    for addr in ip_to_features:
        if  addr in ip_to_label           and  \
            ip_to_features[addr] != None  and  \
            ip_to_label[addr]    != []         :
            
            curr_addr_features = ip_to_features[addr]
            curr_addr_label    = get_os_label(ip_to_label[addr])
            
            if len(curr_addr_label) != 0:
                try:
                    curr_addr_features = preprocess_curr_addr_features(curr_addr_features, curr_addr_label)
                    all_data.append(curr_addr_features)
                except Exception as e:
                    print(f'error on {filename}')
                    raise e

    feature_file.close()
    label_file.close()

all_data_df = pd.DataFrame.from_dict(all_data)
all_data_df['opts_str'] = all_data_df['opts'].copy(deep=True)
all_data_df['opts'] = LabelEncoder().fit_transform(all_data_df['opts'])

# %%
with pd.option_context("display.max_rows", 1000):
    print(all_data_df['label'].value_counts())

# %%
# get rid of datapoints with a rare OS
os_counts   = all_data_df.groupby('label').size().to_dict()
common_os   = [os  for os in os_counts  if  os_counts[os] > 4000]
all_data_df = all_data_df.loc[all_data_df['label'].isin(common_os)]

# balance the dataset
for label in all_data_df['label'].unique():
    tmp_df      = all_data_df[all_data_df['label'] == label]
    all_data_df = all_data_df[all_data_df['label'] != label]
    all_data_df = pd.concat([all_data_df, tmp_df[:4000]])

# shuffle dataframe
all_data_df = all_data_df.sample(frac=1)

# create feature matrix
NUM_CLASSES = all_data_df['label'].nunique()

X = all_data_df.drop('label', axis=1).drop('opts_str', axis=1)

# %%
# pd.set_option('display.max_rows', 500)
# pd.set_option('display.max_columns', 500)
# pd.set_option('display.width', 1000)
# print(all_data_df.sort_values('label'))

# %%
with pd.option_context("display.max_rows", 1000):
    print(all_data_df['label'].value_counts())
# Out:
# Linux_2.6.X      4000
# Windows_2016     4000
# Linux_5.X        4000
# Linux_None       4000
# OpenBSD_4.X      4000
# Windows_2012     4000
# Linux_3.X        4000
# FreeBSD_6.X      4000
# embedded_None    4000
# Linux_4.X        4000
# Name: label, dtype: int64

# %%
with pd.option_context("display.max_rows", 1000):
    for column in all_data_df.columns:
        print(column)
        print(all_data_df[column].value_counts())

# %%
y      = LabelEncoder().fit_transform(all_data_df['label'])
labels = sorted(np.unique(y))


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11235)

ct = make_column_transformer(
    # (MinMaxScaler(), ['w_size', 'mss']),
    # (OneHotEncoder(handle_unknown="ignore"), ['w_scale'] + ['opt%d' % (i) for i in range(10)]),
    (OneHotEncoder(handle_unknown="ignore"), ['w_size', 'df', 'df+', 'df-', 'fo+', 'fo-', 'ecn', 'seq0', 'ttl', 'w_scale', 'opts']),
    remainder='passthrough'
)
ct.fit(X_train)

X_train_normal, X_test_normal = ct.transform(X_train), ct.transform(X_test)


svm_classifier = svm.SVC(kernel='linear', probability=True, C=1, decision_function_shape='ovo').fit(X_train_normal, y_train)
y_preds = svm_classifier.predict_proba(X_test_normal)
print(f'linear score (accuracy)\t: {svm_classifier.score(X_test_normal, y_test)}')
print(f'\tlinear score (top-2)\t: {top_k_accuracy_score(y_test, y_preds, k=2, labels=labels)}')

svm_classifier = svm.SVC(kernel='rbf',    probability=True, C=1, decision_function_shape='ovo').fit(X_train_normal, y_train)
y_preds = svm_classifier.predict_proba(X_test_normal)
print(f'rbf score (accuracy)\t: {svm_classifier.score(X_test_normal, y_test)}')
print(f'\tlinear score (top-2)\t: {top_k_accuracy_score(y_test, y_preds, k=2, labels=labels)}')

svm_classifier = svm.SVC(kernel='poly',   probability=True, C=c, decision_function_shape='ovo').fit(X_train_normal, y_train)
y_preds = svm_classifier.predict_proba(X_test_normal)
print(f'poly score (accuracy)\t: {svm_classifier.score(X_test_normal, y_test)}')
print(f'\tlinear score (top-2)\t: {top_k_accuracy_score(y_test, y_preds, k=2, labels=labels)}')

# %%
y = LabelBinarizer().fit_transform(all_data_df['label'])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=11235)

# unique, counts = np.unique(list(map(lambda arr : list(arr).index(1), y_train)), return_counts=True)
# print(np.asarray((unique, counts)).T)
# print('----------------')
# unique, counts = np.unique(list(map(lambda arr : list(arr).index(1), y_test)), return_counts=True)
# print(np.asarray((unique, counts)).T)

ct = make_column_transformer(
    # (MinMaxScaler(), ['w_size', 'mss']),
    # (OneHotEncoder(handle_unknown="ignore"), ['w_scale'] + ['opt%d' % (i) for i in range(10)]),
    (OneHotEncoder(handle_unknown="ignore"), ['w_size', 'df', 'df+', 'df-', 'fo+', 'fo-', 'ecn', 'seq0', 'ttl', 'w_scale', 'opts']),
    remainder='passthrough'
)
ct.fit(X_train)

X_train_normal, X_test_normal = ct.transform(X_train), ct.transform(X_test)


tf.random.set_seed(11235)

model = tf.keras.Sequential([
    tf.keras.layers.Dense(50, input_dim=X_train_normal.shape[1], activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(30, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(20, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(10, activation='relu', kernel_initializer='he_uniform'),
    tf.keras.layers.Dense(len(y_train[0]), activation='softmax', kernel_initializer='he_uniform')
])

model_metrics = ['categorical_accuracy', 
                 tf.metrics.TopKCategoricalAccuracy(k=2)]
                
model.compile(loss='categorical_crossentropy', \
              #optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), \
              optimizer='sgd', \
              metrics=model_metrics, \
              steps_per_execution=50)

history = model.fit(X_train_normal, y_train, epochs=5000, batch_size=256, verbose=2)
# Out:
# Epoch 1/5000
# 125/125 - 1s - loss: 2.2039 - categorical_accuracy: 0.0937 - top_k_categorical_accuracy: 0.3063 - 1s/epoch - 10ms/step
# Epoch 2/5000
# 125/125 - 0s - loss: 2.0707 - categorical_accuracy: 0.1627 - top_k_categorical_accuracy: 0.3323 - 266ms/epoch - 2ms/step
# Epoch 3/5000
# 125/125 - 0s - loss: 1.9240 - categorical_accuracy: 0.2710 - top_k_categorical_accuracy: 0.4416 - 268ms/epoch - 2ms/step
# Epoch 4/5000
# 125/125 - 0s - loss: 1.7623 - categorical_accuracy: 0.3574 - top_k_categorical_accuracy: 0.5759 - 288ms/epoch - 2ms/step
# Epoch 5/5000
# 125/125 - 0s - loss: 1.6290 - categorical_accuracy: 0.3627 - top_k_categorical_accuracy: 0.6699 - 279ms/epoch - 2ms/step
# Epoch 6/5000
# 125/125 - 0s - loss: 1.5460 - categorical_accuracy: 0.4333 - top_k_categorical_accuracy: 0.6880 - 270ms/epoch - 2ms/step
# Epoch 7/5000
# 125/125 - 0s - loss: 1.4856 - categorical_accuracy: 0.4803 - top_k_categorical_accuracy: 0.6916 - 295ms/epoch - 2ms/step
# Epoch 8/5000
# 125/125 - 0s - loss: 1.4352 - categorical_accuracy: 0.4839 - top_k_categorical_accuracy: 0.7029 - 304ms/epoch - 2ms/step
# Epoch 9/5000
# 125/125 - 0s - loss: 1.3882 - categorical_accuracy: 0.4850 - top_k_categorical_accuracy: 0.7270 - 323ms/epoch - 3ms/step
# Epoch 10/5000
# 125/125 - 0s - loss: 1.3447 - categorical_accuracy: 0.4969 - top_k_categorical_accuracy: 0.7436 - 284ms/epoch - 2ms/step
# Epoch 11/5000
# 125/125 - 1s - loss: 1.3103 - categorical_accuracy: 0.5107 - top_k_categorical_accuracy: 0.7539 - 536ms/epoch - 4ms/step
# Epoch 12/5000
# 125/125 - 1s - loss: 1.2830 - categorical_accuracy: 0.5117 - top_k_categorical_accuracy: 0.7669 - 706ms/epoch - 6ms/step
# Epoch 13/5000
# 125/125 - 0s - loss: 1.2601 - categorical_accuracy: 0.5124 - top_k_categorical_accuracy: 0.7707 - 321ms/epoch - 3ms/step
# Epoch 14/5000
# 125/125 - 0s - loss: 1.2414 - categorical_accuracy: 0.5275 - top_k_categorical_accuracy: 0.7787 - 278ms/epoch - 2ms/step
# Epoch 15/5000
# 125/125 - 1s - loss: 1.2257 - categorical_accuracy: 0.5362 - top_k_categorical_accuracy: 0.8008 - 629ms/epoch - 5ms/step
# Epoch 16/5000
# 125/125 - 1s - loss: 1.2139 - categorical_accuracy: 0.5412 - top_k_categorical_accuracy: 0.8128 - 540ms/epoch - 4ms/step
# Epoch 17/5000
# 125/125 - 1s - loss: 1.2023 - categorical_accuracy: 0.5477 - top_k_categorical_accuracy: 0.8152 - 684ms/epoch - 5ms/step
# Epoch 18/5000
# 125/125 - 0s - loss: 1.1933 - categorical_accuracy: 0.5521 - top_k_categorical_accuracy: 0.8174 - 320ms/epoch - 3ms/step
# Epoch 19/5000
# 125/125 - 0s - loss: 1.1855 - categorical_accuracy: 0.5554 - top_k_categorical_accuracy: 0.8192 - 272ms/epoch - 2ms/step
# Epoch 20/5000
# 125/125 - 0s - loss: 1.1785 - categorical_accuracy: 0.5559 - top_k_categorical_accuracy: 0.8206 - 266ms/epoch - 2ms/step
# Epoch 21/5000
# 125/125 - 0s - loss: 1.1725 - categorical_accuracy: 0.5595 - top_k_categorical_accuracy: 0.8217 - 275ms/epoch - 2ms/step
# Epoch 22/5000
# 125/125 - 0s - loss: 1.1666 - categorical_accuracy: 0.5568 - top_k_categorical_accuracy: 0.8241 - 271ms/epoch - 2ms/step
# Epoch 23/5000
# 125/125 - 0s - loss: 1.1611 - categorical_accuracy: 0.5601 - top_k_categorical_accuracy: 0.8301 - 272ms/epoch - 2ms/step
# Epoch 24/5000
# 125/125 - 0s - loss: 1.1565 - categorical_accuracy: 0.5592 - top_k_categorical_accuracy: 0.8297 - 263ms/epoch - 2ms/step
# Epoch 25/5000
# 125/125 - 0s - loss: 1.1527 - categorical_accuracy: 0.5606 - top_k_categorical_accuracy: 0.8329 - 273ms/epoch - 2ms/step
# Epoch 26/5000
# 125/125 - 0s - loss: 1.1483 - categorical_accuracy: 0.5591 - top_k_categorical_accuracy: 0.8346 - 357ms/epoch - 3ms/step
# Epoch 27/5000
# 125/125 - 0s - loss: 1.1442 - categorical_accuracy: 0.5611 - top_k_categorical_accuracy: 0.8363 - 458ms/epoch - 4ms/step
# Epoch 28/5000
# 125/125 - 0s - loss: 1.1407 - categorical_accuracy: 0.5635 - top_k_categorical_accuracy: 0.8374 - 369ms/epoch - 3ms/step
# Epoch 29/5000
# 125/125 - 0s - loss: 1.1367 - categorical_accuracy: 0.5624 - top_k_categorical_accuracy: 0.8380 - 307ms/epoch - 2ms/step
# Epoch 30/5000
# 125/125 - 0s - loss: 1.1335 - categorical_accuracy: 0.5637 - top_k_categorical_accuracy: 0.8410 - 288ms/epoch - 2ms/step
# Epoch 31/5000
# 125/125 - 0s - loss: 1.1308 - categorical_accuracy: 0.5641 - top_k_categorical_accuracy: 0.8392 - 389ms/epoch - 3ms/step
# Epoch 32/5000
# 125/125 - 0s - loss: 1.1278 - categorical_accuracy: 0.5671 - top_k_categorical_accuracy: 0.8382 - 281ms/epoch - 2ms/step
# Epoch 33/5000
# 125/125 - 0s - loss: 1.1253 - categorical_accuracy: 0.5667 - top_k_categorical_accuracy: 0.8402 - 280ms/epoch - 2ms/step
# Epoch 34/5000
# 125/125 - 0s - loss: 1.1229 - categorical_accuracy: 0.5660 - top_k_categorical_accuracy: 0.8395 - 278ms/epoch - 2ms/step
# Epoch 35/5000
# 125/125 - 0s - loss: 1.1202 - categorical_accuracy: 0.5675 - top_k_categorical_accuracy: 0.8405 - 265ms/epoch - 2ms/step
# Epoch 36/5000
# 125/125 - 0s - loss: 1.1176 - categorical_accuracy: 0.5657 - top_k_categorical_accuracy: 0.8411 - 276ms/epoch - 2ms/step
# Epoch 37/5000
# 125/125 - 0s - loss: 1.1150 - categorical_accuracy: 0.5663 - top_k_categorical_accuracy: 0.8431 - 277ms/epoch - 2ms/step
# Epoch 38/5000
# 125/125 - 0s - loss: 1.1139 - categorical_accuracy: 0.5664 - top_k_categorical_accuracy: 0.8425 - 278ms/epoch - 2ms/step
# Epoch 39/5000
# 125/125 - 0s - loss: 1.1110 - categorical_accuracy: 0.5680 - top_k_categorical_accuracy: 0.8421 - 278ms/epoch - 2ms/step
# Epoch 40/5000
# 125/125 - 0s - loss: 1.1096 - categorical_accuracy: 0.5654 - top_k_categorical_accuracy: 0.8440 - 275ms/epoch - 2ms/step
# Epoch 41/5000
# 125/125 - 0s - loss: 1.1079 - categorical_accuracy: 0.5689 - top_k_categorical_accuracy: 0.8434 - 271ms/epoch - 2ms/step
# Epoch 42/5000
# 125/125 - 0s - loss: 1.1060 - categorical_accuracy: 0.5686 - top_k_categorical_accuracy: 0.8435 - 273ms/epoch - 2ms/step
# Epoch 43/5000
# 125/125 - 0s - loss: 1.1042 - categorical_accuracy: 0.5698 - top_k_categorical_accuracy: 0.8455 - 376ms/epoch - 3ms/step
# Epoch 44/5000
# 125/125 - 0s - loss: 1.1028 - categorical_accuracy: 0.5711 - top_k_categorical_accuracy: 0.8442 - 435ms/epoch - 3ms/step
# Epoch 45/5000
# 125/125 - 0s - loss: 1.1011 - categorical_accuracy: 0.5704 - top_k_categorical_accuracy: 0.8462 - 362ms/epoch - 3ms/step
# Epoch 46/5000
# 125/125 - 0s - loss: 1.0997 - categorical_accuracy: 0.5694 - top_k_categorical_accuracy: 0.8453 - 342ms/epoch - 3ms/step
# Epoch 47/5000
# 125/125 - 0s - loss: 1.0981 - categorical_accuracy: 0.5712 - top_k_categorical_accuracy: 0.8457 - 420ms/epoch - 3ms/step
# Epoch 48/5000
# 125/125 - 0s - loss: 1.0971 - categorical_accuracy: 0.5742 - top_k_categorical_accuracy: 0.8456 - 414ms/epoch - 3ms/step
# Epoch 49/5000
# 125/125 - 0s - loss: 1.0952 - categorical_accuracy: 0.5752 - top_k_categorical_accuracy: 0.8455 - 410ms/epoch - 3ms/step
# Epoch 50/5000
# 125/125 - 0s - loss: 1.0947 - categorical_accuracy: 0.5736 - top_k_categorical_accuracy: 0.8458 - 379ms/epoch - 3ms/step
# Epoch 51/5000
# 125/125 - 0s - loss: 1.0931 - categorical_accuracy: 0.5777 - top_k_categorical_accuracy: 0.8462 - 461ms/epoch - 4ms/step
# Epoch 52/5000
# 125/125 - 0s - loss: 1.0920 - categorical_accuracy: 0.5751 - top_k_categorical_accuracy: 0.8465 - 454ms/epoch - 4ms/step
# Epoch 53/5000
# 125/125 - 0s - loss: 1.0906 - categorical_accuracy: 0.5766 - top_k_categorical_accuracy: 0.8471 - 423ms/epoch - 3ms/step
# Epoch 54/5000
# 125/125 - 0s - loss: 1.0895 - categorical_accuracy: 0.5759 - top_k_categorical_accuracy: 0.8473 - 344ms/epoch - 3ms/step
# Epoch 55/5000
# 125/125 - 0s - loss: 1.0887 - categorical_accuracy: 0.5756 - top_k_categorical_accuracy: 0.8469 - 363ms/epoch - 3ms/step
# Epoch 56/5000
# 125/125 - 0s - loss: 1.0877 - categorical_accuracy: 0.5777 - top_k_categorical_accuracy: 0.8471 - 413ms/epoch - 3ms/step
# Epoch 57/5000
# 125/125 - 0s - loss: 1.0870 - categorical_accuracy: 0.5769 - top_k_categorical_accuracy: 0.8471 - 402ms/epoch - 3ms/step
# Epoch 58/5000
# 125/125 - 0s - loss: 1.0859 - categorical_accuracy: 0.5802 - top_k_categorical_accuracy: 0.8467 - 404ms/epoch - 3ms/step
# Epoch 59/5000
# 125/125 - 0s - loss: 1.0850 - categorical_accuracy: 0.5770 - top_k_categorical_accuracy: 0.8476 - 366ms/epoch - 3ms/step
# Epoch 60/5000
# 125/125 - 0s - loss: 1.0843 - categorical_accuracy: 0.5782 - top_k_categorical_accuracy: 0.8477 - 380ms/epoch - 3ms/step
# Epoch 61/5000
# 125/125 - 0s - loss: 1.0831 - categorical_accuracy: 0.5791 - top_k_categorical_accuracy: 0.8476 - 426ms/epoch - 3ms/step
# Epoch 62/5000
# 125/125 - 0s - loss: 1.0829 - categorical_accuracy: 0.5782 - top_k_categorical_accuracy: 0.8471 - 366ms/epoch - 3ms/step
# Epoch 63/5000
# 125/125 - 0s - loss: 1.0817 - categorical_accuracy: 0.5788 - top_k_categorical_accuracy: 0.8480 - 410ms/epoch - 3ms/step
# Epoch 64/5000
# 125/125 - 0s - loss: 1.0808 - categorical_accuracy: 0.5800 - top_k_categorical_accuracy: 0.8468 - 408ms/epoch - 3ms/step
# Epoch 65/5000
# 125/125 - 0s - loss: 1.0804 - categorical_accuracy: 0.5780 - top_k_categorical_accuracy: 0.8478 - 387ms/epoch - 3ms/step
# Epoch 66/5000
# 125/125 - 0s - loss: 1.0797 - categorical_accuracy: 0.5785 - top_k_categorical_accuracy: 0.8478 - 413ms/epoch - 3ms/step
# Epoch 67/5000
# 125/125 - 0s - loss: 1.0791 - categorical_accuracy: 0.5807 - top_k_categorical_accuracy: 0.8482 - 375ms/epoch - 3ms/step
# Epoch 68/5000
# 125/125 - 0s - loss: 1.0781 - categorical_accuracy: 0.5808 - top_k_categorical_accuracy: 0.8480 - 385ms/epoch - 3ms/step
# Epoch 69/5000
# 125/125 - 0s - loss: 1.0773 - categorical_accuracy: 0.5800 - top_k_categorical_accuracy: 0.8485 - 362ms/epoch - 3ms/step
# Epoch 70/5000
# 125/125 - 0s - loss: 1.0772 - categorical_accuracy: 0.5786 - top_k_categorical_accuracy: 0.8479 - 451ms/epoch - 4ms/step
# Epoch 71/5000
# 125/125 - 0s - loss: 1.0770 - categorical_accuracy: 0.5797 - top_k_categorical_accuracy: 0.8486 - 436ms/epoch - 3ms/step
# Epoch 72/5000
# 125/125 - 0s - loss: 1.0758 - categorical_accuracy: 0.5787 - top_k_categorical_accuracy: 0.8489 - 466ms/epoch - 4ms/step
# Epoch 73/5000
# 125/125 - 0s - loss: 1.0754 - categorical_accuracy: 0.5785 - top_k_categorical_accuracy: 0.8485 - 443ms/epoch - 4ms/step
# Epoch 74/5000
# 125/125 - 0s - loss: 1.0746 - categorical_accuracy: 0.5794 - top_k_categorical_accuracy: 0.8484 - 428ms/epoch - 3ms/step
# Epoch 75/5000
# 125/125 - 0s - loss: 1.0738 - categorical_accuracy: 0.5779 - top_k_categorical_accuracy: 0.8491 - 344ms/epoch - 3ms/step
# Epoch 76/5000
# 125/125 - 0s - loss: 1.0738 - categorical_accuracy: 0.5794 - top_k_categorical_accuracy: 0.8492 - 355ms/epoch - 3ms/step
# Epoch 77/5000
# 125/125 - 0s - loss: 1.0727 - categorical_accuracy: 0.5794 - top_k_categorical_accuracy: 0.8492 - 396ms/epoch - 3ms/step
# Epoch 78/5000
# 125/125 - 0s - loss: 1.0723 - categorical_accuracy: 0.5794 - top_k_categorical_accuracy: 0.8490 - 423ms/epoch - 3ms/step
# Epoch 79/5000
# 125/125 - 0s - loss: 1.0725 - categorical_accuracy: 0.5794 - top_k_categorical_accuracy: 0.8495 - 363ms/epoch - 3ms/step
# Epoch 80/5000
# 125/125 - 0s - loss: 1.0712 - categorical_accuracy: 0.5802 - top_k_categorical_accuracy: 0.8498 - 418ms/epoch - 3ms/step
# Epoch 81/5000
# 125/125 - 0s - loss: 1.0712 - categorical_accuracy: 0.5818 - top_k_categorical_accuracy: 0.8497 - 387ms/epoch - 3ms/step
# Epoch 82/5000
# 125/125 - 1s - loss: 1.0702 - categorical_accuracy: 0.5820 - top_k_categorical_accuracy: 0.8499 - 521ms/epoch - 4ms/step
# Epoch 83/5000
# 125/125 - 0s - loss: 1.0698 - categorical_accuracy: 0.5798 - top_k_categorical_accuracy: 0.8503 - 402ms/epoch - 3ms/step
# Epoch 84/5000
# 125/125 - 0s - loss: 1.0696 - categorical_accuracy: 0.5790 - top_k_categorical_accuracy: 0.8499 - 431ms/epoch - 3ms/step
# Epoch 85/5000
# 125/125 - 0s - loss: 1.0687 - categorical_accuracy: 0.5819 - top_k_categorical_accuracy: 0.8503 - 388ms/epoch - 3ms/step
# Epoch 86/5000
# 125/125 - 0s - loss: 1.0682 - categorical_accuracy: 0.5814 - top_k_categorical_accuracy: 0.8505 - 328ms/epoch - 3ms/step
# Epoch 87/5000
# 125/125 - 0s - loss: 1.0680 - categorical_accuracy: 0.5791 - top_k_categorical_accuracy: 0.8503 - 463ms/epoch - 4ms/step
# Epoch 88/5000
# 125/125 - 0s - loss: 1.0681 - categorical_accuracy: 0.5801 - top_k_categorical_accuracy: 0.8505 - 387ms/epoch - 3ms/step
# Epoch 89/5000
# 125/125 - 0s - loss: 1.0680 - categorical_accuracy: 0.5792 - top_k_categorical_accuracy: 0.8505 - 417ms/epoch - 3ms/step
# Epoch 90/5000
# 125/125 - 0s - loss: 1.0672 - categorical_accuracy: 0.5815 - top_k_categorical_accuracy: 0.8505 - 368ms/epoch - 3ms/step
# Epoch 91/5000
# 125/125 - 0s - loss: 1.0666 - categorical_accuracy: 0.5813 - top_k_categorical_accuracy: 0.8503 - 341ms/epoch - 3ms/step
# Epoch 92/5000
# 125/125 - 0s - loss: 1.0661 - categorical_accuracy: 0.5828 - top_k_categorical_accuracy: 0.8501 - 412ms/epoch - 3ms/step
# Epoch 93/5000
# 125/125 - 0s - loss: 1.0657 - categorical_accuracy: 0.5802 - top_k_categorical_accuracy: 0.8507 - 458ms/epoch - 4ms/step
# Epoch 94/5000
# 125/125 - 0s - loss: 1.0648 - categorical_accuracy: 0.5813 - top_k_categorical_accuracy: 0.8507 - 401ms/epoch - 3ms/step
# Epoch 95/5000
# 125/125 - 0s - loss: 1.0649 - categorical_accuracy: 0.5828 - top_k_categorical_accuracy: 0.8507 - 374ms/epoch - 3ms/step
# Epoch 96/5000
# 125/125 - 0s - loss: 1.0643 - categorical_accuracy: 0.5811 - top_k_categorical_accuracy: 0.8508 - 373ms/epoch - 3ms/step
# Epoch 97/5000
# 125/125 - 0s - loss: 1.0641 - categorical_accuracy: 0.5824 - top_k_categorical_accuracy: 0.8508 - 373ms/epoch - 3ms/step
# Epoch 98/5000
# 125/125 - 0s - loss: 1.0637 - categorical_accuracy: 0.5825 - top_k_categorical_accuracy: 0.8507 - 360ms/epoch - 3ms/step
# Epoch 99/5000
# 125/125 - 0s - loss: 1.0636 - categorical_accuracy: 0.5802 - top_k_categorical_accuracy: 0.8509 - 407ms/epoch - 3ms/step
# Epoch 100/5000
# 125/125 - 0s - loss: 1.0630 - categorical_accuracy: 0.5816 - top_k_categorical_accuracy: 0.8509 - 420ms/epoch - 3ms/step
# Epoch 101/5000
# 125/125 - 1s - loss: 1.0629 - categorical_accuracy: 0.5813 - top_k_categorical_accuracy: 0.8508 - 523ms/epoch - 4ms/step
# Epoch 102/5000
# 125/125 - 0s - loss: 1.0620 - categorical_accuracy: 0.5809 - top_k_categorical_accuracy: 0.8511 - 438ms/epoch - 4ms/step
# Epoch 103/5000
# 125/125 - 0s - loss: 1.0623 - categorical_accuracy: 0.5816 - top_k_categorical_accuracy: 0.8509 - 354ms/epoch - 3ms/step
# Epoch 104/5000
# 125/125 - 0s - loss: 1.0612 - categorical_accuracy: 0.5802 - top_k_categorical_accuracy: 0.8512 - 339ms/epoch - 3ms/step
# Epoch 105/5000
# 125/125 - 0s - loss: 1.0606 - categorical_accuracy: 0.5814 - top_k_categorical_accuracy: 0.8512 - 441ms/epoch - 4ms/step
# Epoch 106/5000
# 125/125 - 0s - loss: 1.0610 - categorical_accuracy: 0.5838 - top_k_categorical_accuracy: 0.8509 - 457ms/epoch - 4ms/step
# Epoch 107/5000
# 125/125 - 0s - loss: 1.0602 - categorical_accuracy: 0.5832 - top_k_categorical_accuracy: 0.8510 - 403ms/epoch - 3ms/step
# Epoch 108/5000
# 125/125 - 0s - loss: 1.0603 - categorical_accuracy: 0.5820 - top_k_categorical_accuracy: 0.8514 - 427ms/epoch - 3ms/step
# Epoch 109/5000
# 125/125 - 0s - loss: 1.0601 - categorical_accuracy: 0.5830 - top_k_categorical_accuracy: 0.8513 - 477ms/epoch - 4ms/step
# Epoch 110/5000
# 125/125 - 0s - loss: 1.0595 - categorical_accuracy: 0.5826 - top_k_categorical_accuracy: 0.8511 - 431ms/epoch - 3ms/step
# Epoch 111/5000
# 125/125 - 0s - loss: 1.0595 - categorical_accuracy: 0.5844 - top_k_categorical_accuracy: 0.8514 - 472ms/epoch - 4ms/step
# Epoch 112/5000
# 125/125 - 0s - loss: 1.0587 - categorical_accuracy: 0.5838 - top_k_categorical_accuracy: 0.8511 - 388ms/epoch - 3ms/step
# Epoch 113/5000
# 125/125 - 0s - loss: 1.0586 - categorical_accuracy: 0.5824 - top_k_categorical_accuracy: 0.8517 - 423ms/epoch - 3ms/step
# Epoch 114/5000
# 125/125 - 0s - loss: 1.0584 - categorical_accuracy: 0.5842 - top_k_categorical_accuracy: 0.8516 - 385ms/epoch - 3ms/step
# Epoch 115/5000
# 125/125 - 0s - loss: 1.0586 - categorical_accuracy: 0.5820 - top_k_categorical_accuracy: 0.8512 - 406ms/epoch - 3ms/step
# Epoch 116/5000
# 125/125 - 0s - loss: 1.0582 - categorical_accuracy: 0.5831 - top_k_categorical_accuracy: 0.8515 - 372ms/epoch - 3ms/step
# Epoch 117/5000
# 125/125 - 0s - loss: 1.0575 - categorical_accuracy: 0.5814 - top_k_categorical_accuracy: 0.8511 - 357ms/epoch - 3ms/step
# Epoch 118/5000
# 125/125 - 0s - loss: 1.0571 - categorical_accuracy: 0.5841 - top_k_categorical_accuracy: 0.8524 - 396ms/epoch - 3ms/step
# Epoch 119/5000
# 125/125 - 0s - loss: 1.0569 - categorical_accuracy: 0.5841 - top_k_categorical_accuracy: 0.8515 - 416ms/epoch - 3ms/step
# Epoch 120/5000
# 125/125 - 0s - loss: 1.0566 - categorical_accuracy: 0.5849 - top_k_categorical_accuracy: 0.8513 - 416ms/epoch - 3ms/step
# Epoch 121/5000
# 125/125 - 0s - loss: 1.0570 - categorical_accuracy: 0.5829 - top_k_categorical_accuracy: 0.8514 - 420ms/epoch - 3ms/step
# Epoch 122/5000
# 125/125 - 0s - loss: 1.0562 - categorical_accuracy: 0.5827 - top_k_categorical_accuracy: 0.8516 - 372ms/epoch - 3ms/step
# Epoch 123/5000
# 125/125 - 0s - loss: 1.0557 - categorical_accuracy: 0.5854 - top_k_categorical_accuracy: 0.8518 - 408ms/epoch - 3ms/step
# Epoch 124/5000
# 125/125 - 0s - loss: 1.0561 - categorical_accuracy: 0.5827 - top_k_categorical_accuracy: 0.8515 - 359ms/epoch - 3ms/step
# Epoch 125/5000
# 125/125 - 0s - loss: 1.0553 - categorical_accuracy: 0.5848 - top_k_categorical_accuracy: 0.8519 - 386ms/epoch - 3ms/step
# Epoch 126/5000
# 125/125 - 0s - loss: 1.0547 - categorical_accuracy: 0.5838 - top_k_categorical_accuracy: 0.8518 - 365ms/epoch - 3ms/step
# Epoch 127/5000
# 125/125 - 0s - loss: 1.0547 - categorical_accuracy: 0.5845 - top_k_categorical_accuracy: 0.8515 - 346ms/epoch - 3ms/step
# Epoch 128/5000
# 125/125 - 0s - loss: 1.0543 - categorical_accuracy: 0.5843 - top_k_categorical_accuracy: 0.8519 - 412ms/epoch - 3ms/step
# Epoch 129/5000
# 125/125 - 0s - loss: 1.0547 - categorical_accuracy: 0.5828 - top_k_categorical_accuracy: 0.8519 - 429ms/epoch - 3ms/step
# Epoch 130/5000
# 125/125 - 0s - loss: 1.0540 - categorical_accuracy: 0.5842 - top_k_categorical_accuracy: 0.8525 - 427ms/epoch - 3ms/step
# Epoch 131/5000
# 125/125 - 0s - loss: 1.0534 - categorical_accuracy: 0.5837 - top_k_categorical_accuracy: 0.8522 - 434ms/epoch - 3ms/step
# Epoch 132/5000
# 125/125 - 0s - loss: 1.0533 - categorical_accuracy: 0.5846 - top_k_categorical_accuracy: 0.8524 - 446ms/epoch - 4ms/step
# Epoch 133/5000
# 125/125 - 0s - loss: 1.0527 - categorical_accuracy: 0.5845 - top_k_categorical_accuracy: 0.8523 - 458ms/epoch - 4ms/step
# Epoch 134/5000
# 125/125 - 0s - loss: 1.0526 - categorical_accuracy: 0.5861 - top_k_categorical_accuracy: 0.8524 - 352ms/epoch - 3ms/step
# Epoch 135/5000
# 125/125 - 0s - loss: 1.0525 - categorical_accuracy: 0.5829 - top_k_categorical_accuracy: 0.8522 - 397ms/epoch - 3ms/step
# Epoch 136/5000
# 125/125 - 0s - loss: 1.0524 - categorical_accuracy: 0.5810 - top_k_categorical_accuracy: 0.8524 - 402ms/epoch - 3ms/step
# Epoch 137/5000
# 125/125 - 0s - loss: 1.0521 - categorical_accuracy: 0.5849 - top_k_categorical_accuracy: 0.8528 - 386ms/epoch - 3ms/step
# Epoch 138/5000
# 125/125 - 0s - loss: 1.0523 - categorical_accuracy: 0.5835 - top_k_categorical_accuracy: 0.8522 - 367ms/epoch - 3ms/step
# Epoch 139/5000
# 125/125 - 0s - loss: 1.0518 - categorical_accuracy: 0.5829 - top_k_categorical_accuracy: 0.8526 - 405ms/epoch - 3ms/step
# Epoch 140/5000
# 125/125 - 0s - loss: 1.0515 - categorical_accuracy: 0.5833 - top_k_categorical_accuracy: 0.8521 - 408ms/epoch - 3ms/step
# Epoch 141/5000
# 125/125 - 0s - loss: 1.0509 - categorical_accuracy: 0.5821 - top_k_categorical_accuracy: 0.8528 - 396ms/epoch - 3ms/step
# Epoch 142/5000
# 125/125 - 0s - loss: 1.0509 - categorical_accuracy: 0.5850 - top_k_categorical_accuracy: 0.8526 - 359ms/epoch - 3ms/step
# Epoch 143/5000
# 125/125 - 0s - loss: 1.0516 - categorical_accuracy: 0.5839 - top_k_categorical_accuracy: 0.8528 - 367ms/epoch - 3ms/step
# Epoch 144/5000
# 125/125 - 0s - loss: 1.0504 - categorical_accuracy: 0.5847 - top_k_categorical_accuracy: 0.8528 - 383ms/epoch - 3ms/step
# Epoch 145/5000
# 125/125 - 0s - loss: 1.0501 - categorical_accuracy: 0.5859 - top_k_categorical_accuracy: 0.8530 - 450ms/epoch - 4ms/step
# Epoch 146/5000
# 125/125 - 0s - loss: 1.0502 - categorical_accuracy: 0.5861 - top_k_categorical_accuracy: 0.8520 - 377ms/epoch - 3ms/step
# Epoch 147/5000
# 125/125 - 0s - loss: 1.0496 - categorical_accuracy: 0.5837 - top_k_categorical_accuracy: 0.8533 - 373ms/epoch - 3ms/step
# Epoch 148/5000
# 125/125 - 0s - loss: 1.0498 - categorical_accuracy: 0.5838 - top_k_categorical_accuracy: 0.8524 - 402ms/epoch - 3ms/step
# Epoch 149/5000
# 125/125 - 0s - loss: 1.0495 - categorical_accuracy: 0.5863 - top_k_categorical_accuracy: 0.8530 - 348ms/epoch - 3ms/step
# Epoch 150/5000
# 125/125 - 0s - loss: 1.0491 - categorical_accuracy: 0.5853 - top_k_categorical_accuracy: 0.8532 - 371ms/epoch - 3ms/step
# Epoch 151/5000
# 125/125 - 0s - loss: 1.0486 - categorical_accuracy: 0.5853 - top_k_categorical_accuracy: 0.8534 - 467ms/epoch - 4ms/step
# Epoch 152/5000
# 125/125 - 0s - loss: 1.0489 - categorical_accuracy: 0.5825 - top_k_categorical_accuracy: 0.8531 - 460ms/epoch - 4ms/step
# Epoch 153/5000
# 125/125 - 0s - loss: 1.0484 - categorical_accuracy: 0.5853 - top_k_categorical_accuracy: 0.8531 - 398ms/epoch - 3ms/step
# Epoch 154/5000
# 125/125 - 0s - loss: 1.0485 - categorical_accuracy: 0.5850 - top_k_categorical_accuracy: 0.8532 - 359ms/epoch - 3ms/step
# Epoch 155/5000
# 125/125 - 0s - loss: 1.0484 - categorical_accuracy: 0.5814 - top_k_categorical_accuracy: 0.8526 - 386ms/epoch - 3ms/step
# Epoch 156/5000
# 125/125 - 0s - loss: 1.0477 - categorical_accuracy: 0.5832 - top_k_categorical_accuracy: 0.8537 - 462ms/epoch - 4ms/step
# Epoch 157/5000
# 125/125 - 0s - loss: 1.0474 - categorical_accuracy: 0.5854 - top_k_categorical_accuracy: 0.8532 - 400ms/epoch - 3ms/step
# Epoch 158/5000
# 125/125 - 0s - loss: 1.0475 - categorical_accuracy: 0.5864 - top_k_categorical_accuracy: 0.8533 - 437ms/epoch - 3ms/step
# Epoch 159/5000
# 125/125 - 0s - loss: 1.0479 - categorical_accuracy: 0.5849 - top_k_categorical_accuracy: 0.8534 - 410ms/epoch - 3ms/step
# Epoch 160/5000
# 125/125 - 0s - loss: 1.0471 - categorical_accuracy: 0.5836 - top_k_categorical_accuracy: 0.8543 - 377ms/epoch - 3ms/step
# Epoch 161/5000
# 125/125 - 0s - loss: 1.0462 - categorical_accuracy: 0.5868 - top_k_categorical_accuracy: 0.8535 - 366ms/epoch - 3ms/step
# Epoch 162/5000
# 125/125 - 0s - loss: 1.0461 - categorical_accuracy: 0.5867 - top_k_categorical_accuracy: 0.8536 - 343ms/epoch - 3ms/step
# Epoch 163/5000
# 125/125 - 0s - loss: 1.0461 - categorical_accuracy: 0.5857 - top_k_categorical_accuracy: 0.8533 - 416ms/epoch - 3ms/step
# Epoch 164/5000
# 125/125 - 0s - loss: 1.0461 - categorical_accuracy: 0.5872 - top_k_categorical_accuracy: 0.8536 - 391ms/epoch - 3ms/step
# Epoch 165/5000
# 125/125 - 1s - loss: 1.0464 - categorical_accuracy: 0.5835 - top_k_categorical_accuracy: 0.8542 - 504ms/epoch - 4ms/step
# Epoch 166/5000
# 125/125 - 0s - loss: 1.0455 - categorical_accuracy: 0.5827 - top_k_categorical_accuracy: 0.8539 - 365ms/epoch - 3ms/step
# Epoch 167/5000
# 125/125 - 0s - loss: 1.0452 - categorical_accuracy: 0.5843 - top_k_categorical_accuracy: 0.8536 - 482ms/epoch - 4ms/step
# Epoch 168/5000
# 125/125 - 0s - loss: 1.0455 - categorical_accuracy: 0.5851 - top_k_categorical_accuracy: 0.8540 - 400ms/epoch - 3ms/step
# Epoch 169/5000
# 125/125 - 0s - loss: 1.0452 - categorical_accuracy: 0.5873 - top_k_categorical_accuracy: 0.8536 - 384ms/epoch - 3ms/step
# Epoch 170/5000
# 125/125 - 0s - loss: 1.0457 - categorical_accuracy: 0.5866 - top_k_categorical_accuracy: 0.8535 - 391ms/epoch - 3ms/step
# Epoch 171/5000
# 125/125 - 0s - loss: 1.0447 - categorical_accuracy: 0.5847 - top_k_categorical_accuracy: 0.8536 - 338ms/epoch - 3ms/step
# Epoch 172/5000
# 125/125 - 0s - loss: 1.0444 - categorical_accuracy: 0.5842 - top_k_categorical_accuracy: 0.8543 - 276ms/epoch - 2ms/step
# Epoch 173/5000
# 125/125 - 0s - loss: 1.0440 - categorical_accuracy: 0.5876 - top_k_categorical_accuracy: 0.8539 - 256ms/epoch - 2ms/step
# Epoch 174/5000
# 125/125 - 0s - loss: 1.0436 - categorical_accuracy: 0.5857 - top_k_categorical_accuracy: 0.8541 - 281ms/epoch - 2ms/step
# Epoch 175/5000
# 125/125 - 0s - loss: 1.0439 - categorical_accuracy: 0.5849 - top_k_categorical_accuracy: 0.8537 - 255ms/epoch - 2ms/step
# Epoch 176/5000
# 125/125 - 0s - loss: 1.0440 - categorical_accuracy: 0.5834 - top_k_categorical_accuracy: 0.8535 - 273ms/epoch - 2ms/step
# Epoch 177/5000
# 125/125 - 0s - loss: 1.0436 - categorical_accuracy: 0.5858 - top_k_categorical_accuracy: 0.8545 - 258ms/epoch - 2ms/step
# Epoch 178/5000
# 125/125 - 0s - loss: 1.0430 - categorical_accuracy: 0.5869 - top_k_categorical_accuracy: 0.8541 - 272ms/epoch - 2ms/step
# Epoch 179/5000
# 125/125 - 0s - loss: 1.0432 - categorical_accuracy: 0.5854 - top_k_categorical_accuracy: 0.8546 - 261ms/epoch - 2ms/step
# Epoch 180/5000
# 125/125 - 0s - loss: 1.0435 - categorical_accuracy: 0.5861 - top_k_categorical_accuracy: 0.8546 - 255ms/epoch - 2ms/step
# Epoch 181/5000
# 125/125 - 0s - loss: 1.0430 - categorical_accuracy: 0.5884 - top_k_categorical_accuracy: 0.8540 - 267ms/epoch - 2ms/step
# Epoch 182/5000
# 125/125 - 0s - loss: 1.0426 - categorical_accuracy: 0.5865 - top_k_categorical_accuracy: 0.8540 - 271ms/epoch - 2ms/step
# Epoch 183/5000
# 125/125 - 0s - loss: 1.0430 - categorical_accuracy: 0.5850 - top_k_categorical_accuracy: 0.8544 - 261ms/epoch - 2ms/step
# Epoch 184/5000
# 125/125 - 0s - loss: 1.0425 - categorical_accuracy: 0.5862 - top_k_categorical_accuracy: 0.8547 - 263ms/epoch - 2ms/step
# Epoch 185/5000
# 125/125 - 0s - loss: 1.0420 - categorical_accuracy: 0.5864 - top_k_categorical_accuracy: 0.8547 - 256ms/epoch - 2ms/step
# Epoch 186/5000
# 125/125 - 0s - loss: 1.0419 - categorical_accuracy: 0.5856 - top_k_categorical_accuracy: 0.8551 - 467ms/epoch - 4ms/step
# Epoch 187/5000
# 125/125 - 0s - loss: 1.0418 - categorical_accuracy: 0.5872 - top_k_categorical_accuracy: 0.8540 - 273ms/epoch - 2ms/step
# Epoch 188/5000
# 125/125 - 0s - loss: 1.0418 - categorical_accuracy: 0.5847 - top_k_categorical_accuracy: 0.8542 - 271ms/epoch - 2ms/step
# Epoch 189/5000
# 125/125 - 0s - loss: 1.0418 - categorical_accuracy: 0.5885 - top_k_categorical_accuracy: 0.8547 - 263ms/epoch - 2ms/step
# Epoch 190/5000
# 125/125 - 0s - loss: 1.0412 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8553 - 277ms/epoch - 2ms/step
# Epoch 191/5000
# 125/125 - 0s - loss: 1.0410 - categorical_accuracy: 0.5867 - top_k_categorical_accuracy: 0.8545 - 268ms/epoch - 2ms/step
# Epoch 192/5000
# 125/125 - 0s - loss: 1.0405 - categorical_accuracy: 0.5874 - top_k_categorical_accuracy: 0.8548 - 282ms/epoch - 2ms/step
# Epoch 193/5000
# 125/125 - 0s - loss: 1.0413 - categorical_accuracy: 0.5874 - top_k_categorical_accuracy: 0.8548 - 260ms/epoch - 2ms/step
# Epoch 194/5000
# 125/125 - 0s - loss: 1.0404 - categorical_accuracy: 0.5873 - top_k_categorical_accuracy: 0.8549 - 257ms/epoch - 2ms/step
# Epoch 195/5000
# 125/125 - 0s - loss: 1.0404 - categorical_accuracy: 0.5862 - top_k_categorical_accuracy: 0.8552 - 261ms/epoch - 2ms/step
# Epoch 196/5000
# 125/125 - 0s - loss: 1.0398 - categorical_accuracy: 0.5864 - top_k_categorical_accuracy: 0.8549 - 265ms/epoch - 2ms/step
# Epoch 197/5000
# 125/125 - 0s - loss: 1.0405 - categorical_accuracy: 0.5858 - top_k_categorical_accuracy: 0.8545 - 280ms/epoch - 2ms/step
# Epoch 198/5000
# 125/125 - 0s - loss: 1.0398 - categorical_accuracy: 0.5841 - top_k_categorical_accuracy: 0.8552 - 286ms/epoch - 2ms/step
# Epoch 199/5000
# 125/125 - 0s - loss: 1.0409 - categorical_accuracy: 0.5870 - top_k_categorical_accuracy: 0.8545 - 262ms/epoch - 2ms/step
# Epoch 200/5000
# 125/125 - 0s - loss: 1.0396 - categorical_accuracy: 0.5859 - top_k_categorical_accuracy: 0.8546 - 259ms/epoch - 2ms/step
# Epoch 201/5000
# 125/125 - 0s - loss: 1.0402 - categorical_accuracy: 0.5866 - top_k_categorical_accuracy: 0.8553 - 288ms/epoch - 2ms/step
# Epoch 202/5000
# 125/125 - 0s - loss: 1.0400 - categorical_accuracy: 0.5854 - top_k_categorical_accuracy: 0.8548 - 396ms/epoch - 3ms/step
# Epoch 203/5000
# 125/125 - 0s - loss: 1.0395 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8552 - 294ms/epoch - 2ms/step
# Epoch 204/5000
# 125/125 - 0s - loss: 1.0394 - categorical_accuracy: 0.5868 - top_k_categorical_accuracy: 0.8554 - 253ms/epoch - 2ms/step
# Epoch 205/5000
# 125/125 - 0s - loss: 1.0388 - categorical_accuracy: 0.5852 - top_k_categorical_accuracy: 0.8557 - 261ms/epoch - 2ms/step
# Epoch 206/5000
# 125/125 - 0s - loss: 1.0390 - categorical_accuracy: 0.5859 - top_k_categorical_accuracy: 0.8553 - 259ms/epoch - 2ms/step
# Epoch 207/5000
# 125/125 - 0s - loss: 1.0389 - categorical_accuracy: 0.5859 - top_k_categorical_accuracy: 0.8559 - 264ms/epoch - 2ms/step
# Epoch 208/5000
# 125/125 - 0s - loss: 1.0385 - categorical_accuracy: 0.5864 - top_k_categorical_accuracy: 0.8557 - 259ms/epoch - 2ms/step
# Epoch 209/5000
# 125/125 - 0s - loss: 1.0382 - categorical_accuracy: 0.5885 - top_k_categorical_accuracy: 0.8554 - 277ms/epoch - 2ms/step
# Epoch 210/5000
# 125/125 - 0s - loss: 1.0376 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8553 - 276ms/epoch - 2ms/step
# Epoch 211/5000
# 125/125 - 0s - loss: 1.0388 - categorical_accuracy: 0.5862 - top_k_categorical_accuracy: 0.8553 - 257ms/epoch - 2ms/step
# Epoch 212/5000
# 125/125 - 0s - loss: 1.0379 - categorical_accuracy: 0.5861 - top_k_categorical_accuracy: 0.8552 - 307ms/epoch - 2ms/step
# Epoch 213/5000
# 125/125 - 0s - loss: 1.0379 - categorical_accuracy: 0.5876 - top_k_categorical_accuracy: 0.8553 - 347ms/epoch - 3ms/step
# Epoch 214/5000
# 125/125 - 0s - loss: 1.0375 - categorical_accuracy: 0.5883 - top_k_categorical_accuracy: 0.8551 - 262ms/epoch - 2ms/step
# Epoch 215/5000
# 125/125 - 0s - loss: 1.0375 - categorical_accuracy: 0.5876 - top_k_categorical_accuracy: 0.8549 - 262ms/epoch - 2ms/step
# Epoch 216/5000
# 125/125 - 0s - loss: 1.0373 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8552 - 254ms/epoch - 2ms/step
# Epoch 217/5000
# 125/125 - 0s - loss: 1.0374 - categorical_accuracy: 0.5873 - top_k_categorical_accuracy: 0.8560 - 276ms/epoch - 2ms/step
# Epoch 218/5000
# 125/125 - 0s - loss: 1.0368 - categorical_accuracy: 0.5853 - top_k_categorical_accuracy: 0.8556 - 259ms/epoch - 2ms/step
# Epoch 219/5000
# 125/125 - 0s - loss: 1.0371 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8554 - 333ms/epoch - 3ms/step
# Epoch 220/5000
# 125/125 - 0s - loss: 1.0361 - categorical_accuracy: 0.5895 - top_k_categorical_accuracy: 0.8560 - 259ms/epoch - 2ms/step
# Epoch 221/5000
# 125/125 - 0s - loss: 1.0367 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8558 - 313ms/epoch - 3ms/step
# Epoch 222/5000
# 125/125 - 0s - loss: 1.0365 - categorical_accuracy: 0.5882 - top_k_categorical_accuracy: 0.8559 - 270ms/epoch - 2ms/step
# Epoch 223/5000
# 125/125 - 0s - loss: 1.0361 - categorical_accuracy: 0.5882 - top_k_categorical_accuracy: 0.8561 - 258ms/epoch - 2ms/step
# Epoch 224/5000
# 125/125 - 0s - loss: 1.0360 - categorical_accuracy: 0.5859 - top_k_categorical_accuracy: 0.8549 - 264ms/epoch - 2ms/step
# Epoch 225/5000
# 125/125 - 0s - loss: 1.0359 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8564 - 287ms/epoch - 2ms/step
# Epoch 226/5000
# 125/125 - 0s - loss: 1.0360 - categorical_accuracy: 0.5877 - top_k_categorical_accuracy: 0.8562 - 276ms/epoch - 2ms/step
# Epoch 227/5000
# 125/125 - 0s - loss: 1.0357 - categorical_accuracy: 0.5862 - top_k_categorical_accuracy: 0.8559 - 275ms/epoch - 2ms/step
# Epoch 228/5000
# 125/125 - 0s - loss: 1.0358 - categorical_accuracy: 0.5869 - top_k_categorical_accuracy: 0.8562 - 416ms/epoch - 3ms/step
# Epoch 229/5000
# 125/125 - 0s - loss: 1.0355 - categorical_accuracy: 0.5856 - top_k_categorical_accuracy: 0.8562 - 293ms/epoch - 2ms/step
# Epoch 230/5000
# 125/125 - 0s - loss: 1.0355 - categorical_accuracy: 0.5870 - top_k_categorical_accuracy: 0.8562 - 284ms/epoch - 2ms/step
# Epoch 231/5000
# 125/125 - 0s - loss: 1.0351 - categorical_accuracy: 0.5875 - top_k_categorical_accuracy: 0.8565 - 251ms/epoch - 2ms/step
# Epoch 232/5000
# 125/125 - 0s - loss: 1.0347 - categorical_accuracy: 0.5913 - top_k_categorical_accuracy: 0.8562 - 269ms/epoch - 2ms/step
# Epoch 233/5000
# 125/125 - 0s - loss: 1.0346 - categorical_accuracy: 0.5883 - top_k_categorical_accuracy: 0.8562 - 285ms/epoch - 2ms/step
# Epoch 234/5000
# 125/125 - 0s - loss: 1.0344 - categorical_accuracy: 0.5882 - top_k_categorical_accuracy: 0.8563 - 288ms/epoch - 2ms/step
# Epoch 235/5000
# 125/125 - 0s - loss: 1.0349 - categorical_accuracy: 0.5845 - top_k_categorical_accuracy: 0.8563 - 357ms/epoch - 3ms/step
# Epoch 236/5000
# 125/125 - 0s - loss: 1.0351 - categorical_accuracy: 0.5879 - top_k_categorical_accuracy: 0.8556 - 280ms/epoch - 2ms/step
# Epoch 237/5000
# 125/125 - 0s - loss: 1.0342 - categorical_accuracy: 0.5882 - top_k_categorical_accuracy: 0.8562 - 265ms/epoch - 2ms/step
# Epoch 238/5000
# 125/125 - 0s - loss: 1.0341 - categorical_accuracy: 0.5892 - top_k_categorical_accuracy: 0.8559 - 252ms/epoch - 2ms/step
# Epoch 239/5000
# 125/125 - 0s - loss: 1.0344 - categorical_accuracy: 0.5922 - top_k_categorical_accuracy: 0.8567 - 261ms/epoch - 2ms/step
# Epoch 240/5000
# 125/125 - 0s - loss: 1.0341 - categorical_accuracy: 0.5867 - top_k_categorical_accuracy: 0.8563 - 262ms/epoch - 2ms/step
# Epoch 241/5000
# 125/125 - 0s - loss: 1.0342 - categorical_accuracy: 0.5863 - top_k_categorical_accuracy: 0.8562 - 264ms/epoch - 2ms/step
# Epoch 242/5000
# 125/125 - 0s - loss: 1.0341 - categorical_accuracy: 0.5854 - top_k_categorical_accuracy: 0.8563 - 264ms/epoch - 2ms/step
# Epoch 243/5000
# 125/125 - 0s - loss: 1.0341 - categorical_accuracy: 0.5854 - top_k_categorical_accuracy: 0.8565 - 269ms/epoch - 2ms/step
# Epoch 244/5000
# 125/125 - 0s - loss: 1.0336 - categorical_accuracy: 0.5882 - top_k_categorical_accuracy: 0.8562 - 258ms/epoch - 2ms/step
# Epoch 245/5000
# 125/125 - 1s - loss: 1.0331 - categorical_accuracy: 0.5886 - top_k_categorical_accuracy: 0.8570 - 1s/epoch - 9ms/step
# Epoch 246/5000
# 125/125 - 0s - loss: 1.0329 - categorical_accuracy: 0.5863 - top_k_categorical_accuracy: 0.8558 - 271ms/epoch - 2ms/step
# Epoch 247/5000
# 125/125 - 0s - loss: 1.0332 - categorical_accuracy: 0.5875 - top_k_categorical_accuracy: 0.8563 - 255ms/epoch - 2ms/step
# Epoch 248/5000
# 125/125 - 0s - loss: 1.0327 - categorical_accuracy: 0.5891 - top_k_categorical_accuracy: 0.8566 - 258ms/epoch - 2ms/step
# Epoch 249/5000
# 125/125 - 0s - loss: 1.0327 - categorical_accuracy: 0.5892 - top_k_categorical_accuracy: 0.8565 - 263ms/epoch - 2ms/step
# Epoch 250/5000
# 125/125 - 0s - loss: 1.0331 - categorical_accuracy: 0.5896 - top_k_categorical_accuracy: 0.8565 - 254ms/epoch - 2ms/step
# Epoch 251/5000
# 125/125 - 0s - loss: 1.0321 - categorical_accuracy: 0.5896 - top_k_categorical_accuracy: 0.8566 - 257ms/epoch - 2ms/step
# Epoch 252/5000
# 125/125 - 0s - loss: 1.0326 - categorical_accuracy: 0.5883 - top_k_categorical_accuracy: 0.8566 - 297ms/epoch - 2ms/step
# Epoch 253/5000
# 125/125 - 0s - loss: 1.0325 - categorical_accuracy: 0.5882 - top_k_categorical_accuracy: 0.8565 - 262ms/epoch - 2ms/step
# Epoch 254/5000
# 125/125 - 0s - loss: 1.0319 - categorical_accuracy: 0.5887 - top_k_categorical_accuracy: 0.8568 - 268ms/epoch - 2ms/step
# Epoch 255/5000
# 125/125 - 0s - loss: 1.0323 - categorical_accuracy: 0.5875 - top_k_categorical_accuracy: 0.8570 - 261ms/epoch - 2ms/step
# Epoch 256/5000
# 125/125 - 0s - loss: 1.0320 - categorical_accuracy: 0.5875 - top_k_categorical_accuracy: 0.8564 - 261ms/epoch - 2ms/step
# Epoch 257/5000
# 125/125 - 0s - loss: 1.0322 - categorical_accuracy: 0.5879 - top_k_categorical_accuracy: 0.8572 - 259ms/epoch - 2ms/step
# Epoch 258/5000
# 125/125 - 0s - loss: 1.0318 - categorical_accuracy: 0.5884 - top_k_categorical_accuracy: 0.8572 - 272ms/epoch - 2ms/step
# Epoch 259/5000
# 125/125 - 0s - loss: 1.0316 - categorical_accuracy: 0.5899 - top_k_categorical_accuracy: 0.8572 - 260ms/epoch - 2ms/step
# Epoch 260/5000
# 125/125 - 0s - loss: 1.0315 - categorical_accuracy: 0.5864 - top_k_categorical_accuracy: 0.8569 - 272ms/epoch - 2ms/step
# Epoch 261/5000
# 125/125 - 0s - loss: 1.0311 - categorical_accuracy: 0.5867 - top_k_categorical_accuracy: 0.8570 - 261ms/epoch - 2ms/step
# Epoch 262/5000
# 125/125 - 0s - loss: 1.0313 - categorical_accuracy: 0.5892 - top_k_categorical_accuracy: 0.8571 - 256ms/epoch - 2ms/step
# Epoch 263/5000
# 125/125 - 0s - loss: 1.0311 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8570 - 266ms/epoch - 2ms/step
# Epoch 264/5000
# 125/125 - 0s - loss: 1.0305 - categorical_accuracy: 0.5896 - top_k_categorical_accuracy: 0.8574 - 273ms/epoch - 2ms/step
# Epoch 265/5000
# 125/125 - 0s - loss: 1.0315 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8573 - 253ms/epoch - 2ms/step
# Epoch 266/5000
# 125/125 - 0s - loss: 1.0307 - categorical_accuracy: 0.5886 - top_k_categorical_accuracy: 0.8571 - 297ms/epoch - 2ms/step
# Epoch 267/5000
# 125/125 - 0s - loss: 1.0312 - categorical_accuracy: 0.5886 - top_k_categorical_accuracy: 0.8569 - 279ms/epoch - 2ms/step
# Epoch 268/5000
# 125/125 - 0s - loss: 1.0309 - categorical_accuracy: 0.5871 - top_k_categorical_accuracy: 0.8568 - 312ms/epoch - 2ms/step
# Epoch 269/5000
# 125/125 - 0s - loss: 1.0308 - categorical_accuracy: 0.5893 - top_k_categorical_accuracy: 0.8564 - 270ms/epoch - 2ms/step
# Epoch 270/5000
# 125/125 - 0s - loss: 1.0311 - categorical_accuracy: 0.5875 - top_k_categorical_accuracy: 0.8570 - 255ms/epoch - 2ms/step
# Epoch 271/5000
# 125/125 - 0s - loss: 1.0302 - categorical_accuracy: 0.5894 - top_k_categorical_accuracy: 0.8569 - 268ms/epoch - 2ms/step
# Epoch 272/5000
# 125/125 - 0s - loss: 1.0305 - categorical_accuracy: 0.5906 - top_k_categorical_accuracy: 0.8572 - 261ms/epoch - 2ms/step
# Epoch 273/5000
# 125/125 - 0s - loss: 1.0301 - categorical_accuracy: 0.5874 - top_k_categorical_accuracy: 0.8570 - 263ms/epoch - 2ms/step
# Epoch 274/5000
# 125/125 - 0s - loss: 1.0305 - categorical_accuracy: 0.5895 - top_k_categorical_accuracy: 0.8563 - 271ms/epoch - 2ms/step
# Epoch 275/5000
# 125/125 - 0s - loss: 1.0299 - categorical_accuracy: 0.5884 - top_k_categorical_accuracy: 0.8572 - 257ms/epoch - 2ms/step
# Epoch 276/5000
# 125/125 - 0s - loss: 1.0300 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8576 - 261ms/epoch - 2ms/step
# Epoch 277/5000
# 125/125 - 0s - loss: 1.0301 - categorical_accuracy: 0.5879 - top_k_categorical_accuracy: 0.8575 - 337ms/epoch - 3ms/step
# Epoch 278/5000
# 125/125 - 0s - loss: 1.0294 - categorical_accuracy: 0.5891 - top_k_categorical_accuracy: 0.8574 - 304ms/epoch - 2ms/step
# Epoch 279/5000
# 125/125 - 0s - loss: 1.0295 - categorical_accuracy: 0.5906 - top_k_categorical_accuracy: 0.8569 - 276ms/epoch - 2ms/step
# Epoch 280/5000
# 125/125 - 0s - loss: 1.0294 - categorical_accuracy: 0.5884 - top_k_categorical_accuracy: 0.8573 - 251ms/epoch - 2ms/step
# Epoch 281/5000
# 125/125 - 0s - loss: 1.0289 - categorical_accuracy: 0.5875 - top_k_categorical_accuracy: 0.8573 - 352ms/epoch - 3ms/step
# Epoch 282/5000
# 125/125 - 0s - loss: 1.0297 - categorical_accuracy: 0.5883 - top_k_categorical_accuracy: 0.8574 - 266ms/epoch - 2ms/step
# Epoch 283/5000
# 125/125 - 0s - loss: 1.0290 - categorical_accuracy: 0.5879 - top_k_categorical_accuracy: 0.8576 - 274ms/epoch - 2ms/step
# Epoch 284/5000
# 125/125 - 0s - loss: 1.0286 - categorical_accuracy: 0.5872 - top_k_categorical_accuracy: 0.8574 - 258ms/epoch - 2ms/step
# Epoch 285/5000
# 125/125 - 0s - loss: 1.0288 - categorical_accuracy: 0.5884 - top_k_categorical_accuracy: 0.8575 - 269ms/epoch - 2ms/step
# Epoch 286/5000
# 125/125 - 0s - loss: 1.0289 - categorical_accuracy: 0.5894 - top_k_categorical_accuracy: 0.8575 - 254ms/epoch - 2ms/step
# Epoch 287/5000
# 125/125 - 0s - loss: 1.0287 - categorical_accuracy: 0.5885 - top_k_categorical_accuracy: 0.8575 - 329ms/epoch - 3ms/step
# Epoch 288/5000
# 125/125 - 0s - loss: 1.0290 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8573 - 264ms/epoch - 2ms/step
# Epoch 289/5000
# 125/125 - 0s - loss: 1.0285 - categorical_accuracy: 0.5910 - top_k_categorical_accuracy: 0.8574 - 263ms/epoch - 2ms/step
# Epoch 290/5000
# 125/125 - 0s - loss: 1.0283 - categorical_accuracy: 0.5900 - top_k_categorical_accuracy: 0.8572 - 259ms/epoch - 2ms/step
# Epoch 291/5000
# 125/125 - 0s - loss: 1.0287 - categorical_accuracy: 0.5889 - top_k_categorical_accuracy: 0.8574 - 257ms/epoch - 2ms/step
# Epoch 292/5000
# 125/125 - 0s - loss: 1.0274 - categorical_accuracy: 0.5900 - top_k_categorical_accuracy: 0.8575 - 261ms/epoch - 2ms/step
# Epoch 293/5000
# 125/125 - 0s - loss: 1.0288 - categorical_accuracy: 0.5893 - top_k_categorical_accuracy: 0.8573 - 252ms/epoch - 2ms/step
# Epoch 294/5000
# 125/125 - 0s - loss: 1.0275 - categorical_accuracy: 0.5909 - top_k_categorical_accuracy: 0.8573 - 248ms/epoch - 2ms/step
# Epoch 295/5000
# 125/125 - 0s - loss: 1.0277 - categorical_accuracy: 0.5898 - top_k_categorical_accuracy: 0.8578 - 248ms/epoch - 2ms/step
# Epoch 296/5000
# 125/125 - 0s - loss: 1.0279 - categorical_accuracy: 0.5888 - top_k_categorical_accuracy: 0.8574 - 276ms/epoch - 2ms/step
# Epoch 297/5000
# 125/125 - 0s - loss: 1.0279 - categorical_accuracy: 0.5894 - top_k_categorical_accuracy: 0.8579 - 275ms/epoch - 2ms/step
# Epoch 298/5000
# 125/125 - 0s - loss: 1.0273 - categorical_accuracy: 0.5902 - top_k_categorical_accuracy: 0.8570 - 289ms/epoch - 2ms/step
# Epoch 299/5000
# 125/125 - 0s - loss: 1.0275 - categorical_accuracy: 0.5876 - top_k_categorical_accuracy: 0.8577 - 279ms/epoch - 2ms/step
# Epoch 300/5000
# 125/125 - 0s - loss: 1.0273 - categorical_accuracy: 0.5891 - top_k_categorical_accuracy: 0.8581 - 284ms/epoch - 2ms/step
# Epoch 301/5000
# 125/125 - 0s - loss: 1.0272 - categorical_accuracy: 0.5872 - top_k_categorical_accuracy: 0.8579 - 251ms/epoch - 2ms/step
# Epoch 302/5000
# 125/125 - 0s - loss: 1.0272 - categorical_accuracy: 0.5893 - top_k_categorical_accuracy: 0.8579 - 278ms/epoch - 2ms/step
# Epoch 303/5000
# 125/125 - 0s - loss: 1.0273 - categorical_accuracy: 0.5879 - top_k_categorical_accuracy: 0.8587 - 282ms/epoch - 2ms/step
# Epoch 304/5000
# 125/125 - 1s - loss: 1.0274 - categorical_accuracy: 0.5859 - top_k_categorical_accuracy: 0.8578 - 534ms/epoch - 4ms/step
# Epoch 305/5000
# 125/125 - 0s - loss: 1.0269 - categorical_accuracy: 0.5896 - top_k_categorical_accuracy: 0.8580 - 315ms/epoch - 3ms/step
# Epoch 306/5000
# 125/125 - 0s - loss: 1.0266 - categorical_accuracy: 0.5899 - top_k_categorical_accuracy: 0.8582 - 257ms/epoch - 2ms/step
# Epoch 307/5000
# 125/125 - 0s - loss: 1.0266 - categorical_accuracy: 0.5897 - top_k_categorical_accuracy: 0.8570 - 264ms/epoch - 2ms/step
# Epoch 308/5000
# 125/125 - 0s - loss: 1.0272 - categorical_accuracy: 0.5894 - top_k_categorical_accuracy: 0.8574 - 252ms/epoch - 2ms/step
# Epoch 309/5000
# 125/125 - 0s - loss: 1.0264 - categorical_accuracy: 0.5887 - top_k_categorical_accuracy: 0.8581 - 278ms/epoch - 2ms/step
# Epoch 310/5000
# 125/125 - 0s - loss: 1.0263 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8581 - 252ms/epoch - 2ms/step
# Epoch 311/5000
# 125/125 - 0s - loss: 1.0262 - categorical_accuracy: 0.5869 - top_k_categorical_accuracy: 0.8578 - 258ms/epoch - 2ms/step
# Epoch 312/5000
# 125/125 - 0s - loss: 1.0266 - categorical_accuracy: 0.5896 - top_k_categorical_accuracy: 0.8583 - 255ms/epoch - 2ms/step
# Epoch 313/5000
# 125/125 - 0s - loss: 1.0266 - categorical_accuracy: 0.5885 - top_k_categorical_accuracy: 0.8577 - 292ms/epoch - 2ms/step
# Epoch 314/5000
# 125/125 - 0s - loss: 1.0264 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8581 - 266ms/epoch - 2ms/step
# Epoch 315/5000
# 125/125 - 0s - loss: 1.0256 - categorical_accuracy: 0.5890 - top_k_categorical_accuracy: 0.8579 - 259ms/epoch - 2ms/step
# Epoch 316/5000
# 125/125 - 0s - loss: 1.0255 - categorical_accuracy: 0.5904 - top_k_categorical_accuracy: 0.8581 - 254ms/epoch - 2ms/step
# Epoch 317/5000
# 125/125 - 0s - loss: 1.0268 - categorical_accuracy: 0.5891 - top_k_categorical_accuracy: 0.8585 - 260ms/epoch - 2ms/step
# Epoch 318/5000
# 125/125 - 0s - loss: 1.0255 - categorical_accuracy: 0.5918 - top_k_categorical_accuracy: 0.8575 - 265ms/epoch - 2ms/step
# Epoch 319/5000
# 125/125 - 0s - loss: 1.0257 - categorical_accuracy: 0.5903 - top_k_categorical_accuracy: 0.8583 - 254ms/epoch - 2ms/step
# Epoch 320/5000
# 125/125 - 0s - loss: 1.0250 - categorical_accuracy: 0.5905 - top_k_categorical_accuracy: 0.8575 - 275ms/epoch - 2ms/step
# Epoch 321/5000
# 125/125 - 0s - loss: 1.0256 - categorical_accuracy: 0.5885 - top_k_categorical_accuracy: 0.8581 - 266ms/epoch - 2ms/step
# Epoch 322/5000
# 125/125 - 0s - loss: 1.0258 - categorical_accuracy: 0.5889 - top_k_categorical_accuracy: 0.8578 - 262ms/epoch - 2ms/step
# Epoch 323/5000
# 125/125 - 0s - loss: 1.0253 - categorical_accuracy: 0.5910 - top_k_categorical_accuracy: 0.8576 - 254ms/epoch - 2ms/step
# Epoch 324/5000
# 125/125 - 0s - loss: 1.0254 - categorical_accuracy: 0.5883 - top_k_categorical_accuracy: 0.8586 - 294ms/epoch - 2ms/step
# Epoch 325/5000
# 125/125 - 0s - loss: 1.0250 - categorical_accuracy: 0.5889 - top_k_categorical_accuracy: 0.8579 - 296ms/epoch - 2ms/step
# Epoch 326/5000
# 125/125 - 0s - loss: 1.0250 - categorical_accuracy: 0.5891 - top_k_categorical_accuracy: 0.8582 - 275ms/epoch - 2ms/step
# Epoch 327/5000
# 125/125 - 0s - loss: 1.0249 - categorical_accuracy: 0.5907 - top_k_categorical_accuracy: 0.8583 - 249ms/epoch - 2ms/step
# Epoch 328/5000
# 125/125 - 0s - loss: 1.0248 - categorical_accuracy: 0.5925 - top_k_categorical_accuracy: 0.8577 - 262ms/epoch - 2ms/step
# Epoch 329/5000
# 125/125 - 0s - loss: 1.0246 - categorical_accuracy: 0.5910 - top_k_categorical_accuracy: 0.8578 - 305ms/epoch - 2ms/step
# Epoch 330/5000
# 125/125 - 0s - loss: 1.0246 - categorical_accuracy: 0.5900 - top_k_categorical_accuracy: 0.8578 - 274ms/epoch - 2ms/step
# Epoch 331/5000
# 125/125 - 0s - loss: 1.0248 - categorical_accuracy: 0.5880 - top_k_categorical_accuracy: 0.8579 - 294ms/epoch - 2ms/step
# Epoch 332/5000
# 125/125 - 0s - loss: 1.0245 - categorical_accuracy: 0.5897 - top_k_categorical_accuracy: 0.8584 - 302ms/epoch - 2ms/step
# Epoch 333/5000
# 125/125 - 0s - loss: 1.0243 - categorical_accuracy: 0.5893 - top_k_categorical_accuracy: 0.8584 - 266ms/epoch - 2ms/step
# Epoch 334/5000
# 125/125 - 0s - loss: 1.0249 - categorical_accuracy: 0.5892 - top_k_categorical_accuracy: 0.8584 - 281ms/epoch - 2ms/step
# Epoch 335/5000
# 125/125 - 0s - loss: 1.0246 - categorical_accuracy: 0.5884 - top_k_categorical_accuracy: 0.8580 - 281ms/epoch - 2ms/step
# Epoch 336/5000
# 125/125 - 0s - loss: 1.0240 - categorical_accuracy: 0.5888 - top_k_categorical_accuracy: 0.8578 - 266ms/epoch - 2ms/step
# Epoch 337/5000
# 125/125 - 0s - loss: 1.0245 - categorical_accuracy: 0.5879 - top_k_categorical_accuracy: 0.8582 - 273ms/epoch - 2ms/step
# Epoch 338/5000
# 125/125 - 0s - loss: 1.0237 - categorical_accuracy: 0.5915 - top_k_categorical_accuracy: 0.8583 - 271ms/epoch - 2ms/step
# Epoch 339/5000
# 125/125 - 0s - loss: 1.0243 - categorical_accuracy: 0.5894 - top_k_categorical_accuracy: 0.8585 - 266ms/epoch - 2ms/step
# Epoch 340/5000
# 125/125 - 0s - loss: 1.0240 - categorical_accuracy: 0.5894 - top_k_categorical_accuracy: 0.8583 - 272ms/epoch - 2ms/step
# Epoch 341/5000
# 125/125 - 0s - loss: 1.0239 - categorical_accuracy: 0.5897 - top_k_categorical_accuracy: 0.8579 - 271ms/epoch - 2ms/step
# Epoch 342/5000
# 125/125 - 0s - loss: 1.0239 - categorical_accuracy: 0.5887 - top_k_categorical_accuracy: 0.8581 - 344ms/epoch - 3ms/step
# Epoch 343/5000
# 125/125 - 0s - loss: 1.0234 - categorical_accuracy: 0.5912 - top_k_categorical_accuracy: 0.8584 - 307ms/epoch - 2ms/step
# Epoch 344/5000
# 125/125 - 0s - loss: 1.0231 - categorical_accuracy: 0.5917 - top_k_categorical_accuracy: 0.8584 - 274ms/epoch - 2ms/step
# Epoch 345/5000
# 125/125 - 1s - loss: 1.0238 - categorical_accuracy: 0.5872 - top_k_categorical_accuracy: 0.8579 - 1s/epoch - 11ms/step
# Epoch 346/5000
# 125/125 - 0s - loss: 1.0228 - categorical_accuracy: 0.5907 - top_k_categorical_accuracy: 0.8581 - 378ms/epoch - 3ms/step
# Epoch 347/5000
# 125/125 - 1s - loss: 1.0234 - categorical_accuracy: 0.5895 - top_k_categorical_accuracy: 0.8577 - 666ms/epoch - 5ms/step
# Epoch 348/5000
# 125/125 - 0s - loss: 1.0227 - categorical_accuracy: 0.5907 - top_k_categorical_accuracy: 0.8583 - 351ms/epoch - 3ms/step
# Epoch 349/5000
# 125/125 - 0s - loss: 1.0228 - categorical_accuracy: 0.5914 - top_k_categorical_accuracy: 0.8583 - 268ms/epoch - 2ms/step
# Epoch 350/5000
# 125/125 - 0s - loss: 1.0226 - categorical_accuracy: 0.5883 - top_k_categorical_accuracy: 0.8582 - 290ms/epoch - 2ms/step
# Epoch 351/5000
# 125/125 - 0s - loss: 1.0224 - categorical_accuracy: 0.5903 - top_k_categorical_accuracy: 0.8583 - 275ms/epoch - 2ms/step
# Epoch 352/5000
# 125/125 - 0s - loss: 1.0232 - categorical_accuracy: 0.5878 - top_k_categorical_accuracy: 0.8581 - 295ms/epoch - 2ms/step
# Epoch 353/5000
# 125/125 - 0s - loss: 1.0231 - categorical_accuracy: 0.5911 - top_k_categorical_accuracy: 0.8590 - 474ms/epoch - 4ms/step
# Epoch 354/5000
# ...
# Epoch 923/5000
# 125/125 - 0s - loss: 1.0039 - categorical_accuracy: 0.5911 - top_k_categorical_accuracy: 0.8640 - 360ms/epoch - 3ms/step
# Epoch 924/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5929 - top_k_categorical_accuracy: 0.8636 - 401ms/epoch - 3ms/step
# Epoch 925/5000
# 125/125 - 0s - loss: 1.0044 - categorical_accuracy: 0.5934 - top_k_categorical_accuracy: 0.8639 - 385ms/epoch - 3ms/step
# Epoch 926/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5924 - top_k_categorical_accuracy: 0.8642 - 403ms/epoch - 3ms/step
# Epoch 927/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5943 - top_k_categorical_accuracy: 0.8638 - 383ms/epoch - 3ms/step
# Epoch 928/5000
# 125/125 - 0s - loss: 1.0042 - categorical_accuracy: 0.5941 - top_k_categorical_accuracy: 0.8638 - 408ms/epoch - 3ms/step
# Epoch 929/5000
# 125/125 - 0s - loss: 1.0041 - categorical_accuracy: 0.5927 - top_k_categorical_accuracy: 0.8641 - 444ms/epoch - 4ms/step
# Epoch 930/5000
# 125/125 - 0s - loss: 1.0038 - categorical_accuracy: 0.5937 - top_k_categorical_accuracy: 0.8638 - 399ms/epoch - 3ms/step
# Epoch 931/5000
# 125/125 - 0s - loss: 1.0042 - categorical_accuracy: 0.5931 - top_k_categorical_accuracy: 0.8645 - 385ms/epoch - 3ms/step
# Epoch 932/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5950 - top_k_categorical_accuracy: 0.8644 - 377ms/epoch - 3ms/step
# Epoch 933/5000
# 125/125 - 0s - loss: 1.0040 - categorical_accuracy: 0.5919 - top_k_categorical_accuracy: 0.8638 - 377ms/epoch - 3ms/step
# Epoch 934/5000
# 125/125 - 0s - loss: 1.0035 - categorical_accuracy: 0.5933 - top_k_categorical_accuracy: 0.8633 - 351ms/epoch - 3ms/step
# Epoch 935/5000
# 125/125 - 1s - loss: 1.0038 - categorical_accuracy: 0.5930 - top_k_categorical_accuracy: 0.8643 - 553ms/epoch - 4ms/step
# Epoch 936/5000
# 125/125 - 0s - loss: 1.0037 - categorical_accuracy: 0.5920 - top_k_categorical_accuracy: 0.8642 - 358ms/epoch - 3ms/step
# Epoch 937/5000
# 125/125 - 0s - loss: 1.0042 - categorical_accuracy: 0.5924 - top_k_categorical_accuracy: 0.8648 - 360ms/epoch - 3ms/step
# Epoch 938/5000
# 125/125 - 0s - loss: 1.0040 - categorical_accuracy: 0.5926 - top_k_categorical_accuracy: 0.8639 - 351ms/epoch - 3ms/step
# Epoch 939/5000
# 125/125 - 0s - loss: 1.0040 - categorical_accuracy: 0.5933 - top_k_categorical_accuracy: 0.8639 - 363ms/epoch - 3ms/step
# Epoch 940/5000
# 125/125 - 0s - loss: 1.0039 - categorical_accuracy: 0.5932 - top_k_categorical_accuracy: 0.8645 - 349ms/epoch - 3ms/step
# Epoch 941/5000
# 125/125 - 0s - loss: 1.0034 - categorical_accuracy: 0.5929 - top_k_categorical_accuracy: 0.8647 - 321ms/epoch - 3ms/step
# Epoch 942/5000
# 125/125 - 0s - loss: 1.0034 - categorical_accuracy: 0.5950 - top_k_categorical_accuracy: 0.8631 - 446ms/epoch - 4ms/step
# Epoch 943/5000
# 125/125 - 0s - loss: 1.0035 - categorical_accuracy: 0.5946 - top_k_categorical_accuracy: 0.8640 - 388ms/epoch - 3ms/step
# Epoch 944/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5938 - top_k_categorical_accuracy: 0.8643 - 386ms/epoch - 3ms/step
# Epoch 945/5000
# 125/125 - 1s - loss: 1.0037 - categorical_accuracy: 0.5913 - top_k_categorical_accuracy: 0.8640 - 595ms/epoch - 5ms/step
# Epoch 946/5000
# 125/125 - 0s - loss: 1.0034 - categorical_accuracy: 0.5933 - top_k_categorical_accuracy: 0.8642 - 431ms/epoch - 3ms/step
# Epoch 947/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5933 - top_k_categorical_accuracy: 0.8638 - 406ms/epoch - 3ms/step
# Epoch 948/5000
# 125/125 - 0s - loss: 1.0035 - categorical_accuracy: 0.5941 - top_k_categorical_accuracy: 0.8641 - 396ms/epoch - 3ms/step
# Epoch 949/5000
# 125/125 - 0s - loss: 1.0034 - categorical_accuracy: 0.5957 - top_k_categorical_accuracy: 0.8640 - 369ms/epoch - 3ms/step
# Epoch 950/5000
# 125/125 - 0s - loss: 1.0035 - categorical_accuracy: 0.5935 - top_k_categorical_accuracy: 0.8640 - 376ms/epoch - 3ms/step
# Epoch 951/5000
# 125/125 - 0s - loss: 1.0045 - categorical_accuracy: 0.5919 - top_k_categorical_accuracy: 0.8641 - 416ms/epoch - 3ms/step
# Epoch 952/5000
# 125/125 - 1s - loss: 1.0035 - categorical_accuracy: 0.5941 - top_k_categorical_accuracy: 0.8642 - 1s/epoch - 10ms/step
# Epoch 953/5000
# 125/125 - 1s - loss: 1.0034 - categorical_accuracy: 0.5928 - top_k_categorical_accuracy: 0.8645 - 588ms/epoch - 5ms/step
# Epoch 954/5000
# 125/125 - 1s - loss: 1.0040 - categorical_accuracy: 0.5916 - top_k_categorical_accuracy: 0.8637 - 634ms/epoch - 5ms/step
# Epoch 955/5000
# 125/125 - 0s - loss: 1.0039 - categorical_accuracy: 0.5928 - top_k_categorical_accuracy: 0.8643 - 407ms/epoch - 3ms/step
# Epoch 956/5000
# 125/125 - 0s - loss: 1.0038 - categorical_accuracy: 0.5943 - top_k_categorical_accuracy: 0.8636 - 451ms/epoch - 4ms/step
# Epoch 957/5000
# 125/125 - 0s - loss: 1.0031 - categorical_accuracy: 0.5915 - top_k_categorical_accuracy: 0.8645 - 402ms/epoch - 3ms/step
# Epoch 958/5000
# 125/125 - 1s - loss: 1.0029 - categorical_accuracy: 0.5937 - top_k_categorical_accuracy: 0.8646 - 535ms/epoch - 4ms/step
# Epoch 959/5000
# 125/125 - 0s - loss: 1.0035 - categorical_accuracy: 0.5936 - top_k_categorical_accuracy: 0.8638 - 401ms/epoch - 3ms/step
# Epoch 960/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5916 - top_k_categorical_accuracy: 0.8643 - 437ms/epoch - 3ms/step
# Epoch 961/5000
# 125/125 - 0s - loss: 1.0029 - categorical_accuracy: 0.5945 - top_k_categorical_accuracy: 0.8650 - 416ms/epoch - 3ms/step
# Epoch 962/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5920 - top_k_categorical_accuracy: 0.8641 - 454ms/epoch - 4ms/step
# Epoch 963/5000
# 125/125 - 0s - loss: 1.0034 - categorical_accuracy: 0.5965 - top_k_categorical_accuracy: 0.8644 - 401ms/epoch - 3ms/step
# Epoch 964/5000
# 125/125 - 0s - loss: 1.0038 - categorical_accuracy: 0.5922 - top_k_categorical_accuracy: 0.8637 - 365ms/epoch - 3ms/step
# Epoch 965/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5925 - top_k_categorical_accuracy: 0.8641 - 323ms/epoch - 3ms/step
# Epoch 966/5000
# 125/125 - 0s - loss: 1.0030 - categorical_accuracy: 0.5938 - top_k_categorical_accuracy: 0.8645 - 387ms/epoch - 3ms/step
# Epoch 967/5000
# 125/125 - 0s - loss: 1.0035 - categorical_accuracy: 0.5935 - top_k_categorical_accuracy: 0.8642 - 466ms/epoch - 4ms/step
# Epoch 968/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5943 - top_k_categorical_accuracy: 0.8640 - 421ms/epoch - 3ms/step
# Epoch 969/5000
# 125/125 - 0s - loss: 1.0027 - categorical_accuracy: 0.5924 - top_k_categorical_accuracy: 0.8643 - 409ms/epoch - 3ms/step
# Epoch 970/5000
# 125/125 - 0s - loss: 1.0037 - categorical_accuracy: 0.5929 - top_k_categorical_accuracy: 0.8647 - 379ms/epoch - 3ms/step
# Epoch 971/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5949 - top_k_categorical_accuracy: 0.8640 - 408ms/epoch - 3ms/step
# Epoch 972/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5937 - top_k_categorical_accuracy: 0.8645 - 374ms/epoch - 3ms/step
# Epoch 973/5000
# 125/125 - 0s - loss: 1.0031 - categorical_accuracy: 0.5952 - top_k_categorical_accuracy: 0.8644 - 402ms/epoch - 3ms/step
# Epoch 974/5000
# 125/125 - 0s - loss: 1.0028 - categorical_accuracy: 0.5934 - top_k_categorical_accuracy: 0.8638 - 345ms/epoch - 3ms/step
# Epoch 975/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5918 - top_k_categorical_accuracy: 0.8646 - 459ms/epoch - 4ms/step
# Epoch 976/5000
# 125/125 - 0s - loss: 1.0034 - categorical_accuracy: 0.5936 - top_k_categorical_accuracy: 0.8643 - 495ms/epoch - 4ms/step
# Epoch 977/5000
# 125/125 - 0s - loss: 1.0030 - categorical_accuracy: 0.5946 - top_k_categorical_accuracy: 0.8638 - 418ms/epoch - 3ms/step
# Epoch 978/5000
# 125/125 - 0s - loss: 1.0027 - categorical_accuracy: 0.5923 - top_k_categorical_accuracy: 0.8640 - 437ms/epoch - 3ms/step
# Epoch 979/5000
# 125/125 - 0s - loss: 1.0029 - categorical_accuracy: 0.5950 - top_k_categorical_accuracy: 0.8637 - 309ms/epoch - 2ms/step
# Epoch 980/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5953 - top_k_categorical_accuracy: 0.8642 - 450ms/epoch - 4ms/step
# Epoch 981/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5938 - top_k_categorical_accuracy: 0.8645 - 413ms/epoch - 3ms/step
# Epoch 982/5000
# 125/125 - 0s - loss: 1.0036 - categorical_accuracy: 0.5912 - top_k_categorical_accuracy: 0.8647 - 318ms/epoch - 3ms/step
# Epoch 983/5000
# 125/125 - 0s - loss: 1.0030 - categorical_accuracy: 0.5914 - top_k_categorical_accuracy: 0.8643 - 384ms/epoch - 3ms/step
# Epoch 984/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5920 - top_k_categorical_accuracy: 0.8646 - 362ms/epoch - 3ms/step
# Epoch 985/5000
# 125/125 - 0s - loss: 1.0030 - categorical_accuracy: 0.5936 - top_k_categorical_accuracy: 0.8639 - 393ms/epoch - 3ms/step
# Epoch 986/5000
# 125/125 - 0s - loss: 1.0031 - categorical_accuracy: 0.5935 - top_k_categorical_accuracy: 0.8650 - 490ms/epoch - 4ms/step
# Epoch 987/5000
# 125/125 - 1s - loss: 1.0027 - categorical_accuracy: 0.5936 - top_k_categorical_accuracy: 0.8651 - 707ms/epoch - 6ms/step
# Epoch 988/5000
# 125/125 - 0s - loss: 1.0024 - categorical_accuracy: 0.5928 - top_k_categorical_accuracy: 0.8647 - 408ms/epoch - 3ms/step
# Epoch 989/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5898 - top_k_categorical_accuracy: 0.8645 - 347ms/epoch - 3ms/step
# Epoch 990/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5919 - top_k_categorical_accuracy: 0.8641 - 345ms/epoch - 3ms/step
# Epoch 991/5000
# 125/125 - 0s - loss: 1.0032 - categorical_accuracy: 0.5950 - top_k_categorical_accuracy: 0.8645 - 353ms/epoch - 3ms/step
# Epoch 992/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5956 - top_k_categorical_accuracy: 0.8643 - 341ms/epoch - 3ms/step
# Epoch 993/5000
# 125/125 - 0s - loss: 1.0030 - categorical_accuracy: 0.5934 - top_k_categorical_accuracy: 0.8641 - 399ms/epoch - 3ms/step
# Epoch 994/5000
# 125/125 - 0s - loss: 1.0028 - categorical_accuracy: 0.5926 - top_k_categorical_accuracy: 0.8643 - 319ms/epoch - 3ms/step
# Epoch 995/5000
# 125/125 - 0s - loss: 1.0027 - categorical_accuracy: 0.5932 - top_k_categorical_accuracy: 0.8643 - 410ms/epoch - 3ms/step
# Epoch 996/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5920 - top_k_categorical_accuracy: 0.8638 - 437ms/epoch - 3ms/step
# Epoch 997/5000
# 125/125 - 0s - loss: 1.0024 - categorical_accuracy: 0.5956 - top_k_categorical_accuracy: 0.8646 - 362ms/epoch - 3ms/step
# Epoch 998/5000
# 125/125 - 0s - loss: 1.0031 - categorical_accuracy: 0.5925 - top_k_categorical_accuracy: 0.8645 - 417ms/epoch - 3ms/step
# Epoch 999/5000
# 125/125 - 0s - loss: 1.0033 - categorical_accuracy: 0.5936 - top_k_categorical_accuracy: 0.8645 - 352ms/epoch - 3ms/step
# Epoch 1000/5000
# 125/125 - 0s - loss: 1.0024 - categorical_accuracy: 0.5919 - top_k_categorical_accuracy: 0.8643 - 440ms/epoch - 4ms/step
# Epoch 1001/5000
# 125/125 - 0s - loss: 1.0027 - categorical_accuracy: 0.5928 - top_k_categorical_accuracy: 0.8644 - 397ms/epoch - 3ms/step
# Epoch 1002/5000
# 125/125 - 0s - loss: 1.0022 - categorical_accuracy: 0.5933 - top_k_categorical_accuracy: 0.8644 - 364ms/epoch - 3ms/step
# Epoch 1003/5000
# 125/125 - 0s - loss: 1.0028 - categorical_accuracy: 0.5936 - top_k_categorical_accuracy: 0.8640 - 383ms/epoch - 3ms/step
# Epoch 1004/5000
# 125/125 - 0s - loss: 1.0025 - categorical_accuracy: 0.5939 - top_k_categorical_accuracy: 0.8644 - 381ms/epoch - 3ms/step
# Epoch 1005/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5950 - top_k_categorical_accuracy: 0.8648 - 400ms/epoch - 3ms/step
# Epoch 1006/5000
# 125/125 - 0s - loss: 1.0024 - categorical_accuracy: 0.5929 - top_k_categorical_accuracy: 0.8645 - 400ms/epoch - 3ms/step
# Epoch 1007/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5934 - top_k_categorical_accuracy: 0.8648 - 398ms/epoch - 3ms/step
# Epoch 1008/5000
# 125/125 - 0s - loss: 1.0028 - categorical_accuracy: 0.5924 - top_k_categorical_accuracy: 0.8648 - 381ms/epoch - 3ms/step
# Epoch 1009/5000
# 125/125 - 1s - loss: 1.0026 - categorical_accuracy: 0.5923 - top_k_categorical_accuracy: 0.8649 - 1s/epoch - 9ms/step
# Epoch 1010/5000
# 125/125 - 0s - loss: 1.0021 - categorical_accuracy: 0.5962 - top_k_categorical_accuracy: 0.8644 - 347ms/epoch - 3ms/step
# Epoch 1011/5000
# 125/125 - 0s - loss: 1.0028 - categorical_accuracy: 0.5941 - top_k_categorical_accuracy: 0.8643 - 348ms/epoch - 3ms/step
# Epoch 1012/5000
# 125/125 - 0s - loss: 1.0029 - categorical_accuracy: 0.5931 - top_k_categorical_accuracy: 0.8641 - 370ms/epoch - 3ms/step
# Epoch 1013/5000
# 125/125 - 0s - loss: 1.0020 - categorical_accuracy: 0.5940 - top_k_categorical_accuracy: 0.8642 - 375ms/epoch - 3ms/step
# Epoch 1014/5000
# 125/125 - 0s - loss: 1.0028 - categorical_accuracy: 0.5952 - top_k_categorical_accuracy: 0.8646 - 383ms/epoch - 3ms/step
# Epoch 1015/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5956 - top_k_categorical_accuracy: 0.8648 - 366ms/epoch - 3ms/step
# Epoch 1016/5000
# 125/125 - 0s - loss: 1.0027 - categorical_accuracy: 0.5934 - top_k_categorical_accuracy: 0.8649 - 387ms/epoch - 3ms/step
# Epoch 1017/5000
# 125/125 - 0s - loss: 1.0021 - categorical_accuracy: 0.5930 - top_k_categorical_accuracy: 0.8645 - 400ms/epoch - 3ms/step
# Epoch 1018/5000
# 125/125 - 0s - loss: 1.0020 - categorical_accuracy: 0.5942 - top_k_categorical_accuracy: 0.8647 - 361ms/epoch - 3ms/step
# Epoch 1019/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5927 - top_k_categorical_accuracy: 0.8645 - 424ms/epoch - 3ms/step
# Epoch 1020/5000
# 125/125 - 0s - loss: 1.0020 - categorical_accuracy: 0.5938 - top_k_categorical_accuracy: 0.8647 - 381ms/epoch - 3ms/step
# Epoch 1021/5000
# 125/125 - 0s - loss: 1.0024 - categorical_accuracy: 0.5953 - top_k_categorical_accuracy: 0.8645 - 372ms/epoch - 3ms/step
# Epoch 1022/5000
# 125/125 - 0s - loss: 1.0022 - categorical_accuracy: 0.5949 - top_k_categorical_accuracy: 0.8650 - 402ms/epoch - 3ms/step
# Epoch 1023/5000
# 125/125 - 0s - loss: 1.0023 - categorical_accuracy: 0.5956 - top_k_categorical_accuracy: 0.8644 - 380ms/epoch - 3ms/step
# Epoch 1024/5000
# 125/125 - 0s - loss: 1.0023 - categorical_accuracy: 0.5938 - top_k_categorical_accuracy: 0.8644 - 316ms/epoch - 3ms/step
# Epoch 1025/5000
# 125/125 - 0s - loss: 1.0022 - categorical_accuracy: 0.5926 - top_k_categorical_accuracy: 0.8644 - 384ms/epoch - 3ms/step
# Epoch 1026/5000
# 125/125 - 0s - loss: 1.0023 - categorical_accuracy: 0.5927 - top_k_categorical_accuracy: 0.8643 - 319ms/epoch - 3ms/step
# Epoch 1027/5000
# 125/125 - 0s - loss: 1.0023 - categorical_accuracy: 0.5939 - top_k_categorical_accuracy: 0.8647 - 470ms/epoch - 4ms/step
# Epoch 1028/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5944 - top_k_categorical_accuracy: 0.8644 - 334ms/epoch - 3ms/step
# Epoch 1029/5000
# 125/125 - 0s - loss: 1.0025 - categorical_accuracy: 0.5928 - top_k_categorical_accuracy: 0.8650 - 390ms/epoch - 3ms/step
# Epoch 1030/5000
# 125/125 - 0s - loss: 1.0029 - categorical_accuracy: 0.5922 - top_k_categorical_accuracy: 0.8648 - 398ms/epoch - 3ms/step
# Epoch 1031/5000
# 125/125 - 0s - loss: 1.0021 - categorical_accuracy: 0.5947 - top_k_categorical_accuracy: 0.8644 - 405ms/epoch - 3ms/step
# Epoch 1032/5000
# 125/125 - 0s - loss: 1.0030 - categorical_accuracy: 0.5920 - top_k_categorical_accuracy: 0.8648 - 390ms/epoch - 3ms/step
# Epoch 1033/5000
# 125/125 - 0s - loss: 1.0026 - categorical_accuracy: 0.5919 - top_k_categorical_accuracy: 0.8648 - 355ms/epoch - 3ms/step
# Epoch 1034/5000
# 125/125 - 0s - loss: 1.0012 - categorical_accuracy: 0.5952 - top_k_categorical_accuracy: 0.8641 - 464ms/epoch - 4ms/step
# Epoch 1035/5000
# 125/125 - 0s - loss: 1.0029 - categorical_accuracy: 0.5935 - top_k_categorical_accuracy: 0.8651 - 393ms/epoch - 3ms/step
# Epoch 1036/5000
# 125/125 - 0s - loss: 1.0013 - categorical_accuracy: 0.5924 - top_k_categorical_accuracy: 0.8649 - 350ms/epoch - 3ms/step
# Epoch 1037/5000
# 125/125 - 0s - loss: 1.0018 - categorical_accuracy: 0.5931 - top_k_categorical_accuracy: 0.8647 - 408ms/epoch - 3ms/step
# Epoch 1038/5000
# 125/125 - 0s - loss: 1.0018 - categorical_accuracy: 0.5940 - top_k_categorical_accuracy: 0.8645 - 356ms/epoch - 3ms/step
# Epoch 1039/5000
# 125/125 - 0s - loss: 1.0020 - categorical_accuracy: 0.5942 - top_k_categorical_accuracy: 0.8654 - 353ms/epoch - 3ms/step
# Epoch 1040/5000

# %%
print(history.history['categorical_accuracy'][-1], '\t', history.history['top_k_categorical_accuracy'][-1])

fig, axs = plt.subplots(2)
plt.xlabel('epoch')
axs[0].plot(history.history['top_k_categorical_accuracy'][3:])
axs[1].plot(history.history['loss'][3:])
plt.show()

# %%
class estimator:
  _estimator_type = ''
  classes_=[]
  def __init__(self, model, classes):
    self.model = model
    self._estimator_type = 'classifier'
    self.classes_ = classes
  def predict(self, X):
    y_prob= self.model.predict(X)
    y_pred = y_prob.argmax(axis=1)
    return y_pred

classifier = estimator(model, list(all_data_df['label'].unique()))

figsize = (12,12)
tmp = ConfusionMatrixDisplay.from_estimator(estimator=classifier, 
                                            X=X_test_normal, 
                                            y=y_test.argmax(axis=1), 
                                            cmap='Blues', 
                                            normalize='true', 
                                            ax=plt.subplots(figsize=figsize)[1])
